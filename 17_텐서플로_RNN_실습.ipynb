# %% [markdown]
# <a href="https://colab.research.google.com/github/egag8843/Colab/blob/main/17_%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C_RNN_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2021/0/14
이름 : 장경준
내용: 텐서플로 RNN 실습하기
"""
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import SimpleRNN, Flatten, Dense
from tensorflow.keras.models import Sequential

# %%
# 시계열 데이터 만들기
time = np.arange(365)
month_time = (time % 30) / 30

time_series = 10 * np.where(month_time < 0.5, 
                            np.cos(2 * np.pi * month_time), 
                            np.cos(2 * np.pi * month_time) + np.random.random(365))

# 데이터 시각화
plt.figure(figsize=(10, 5))
plt.xlabel('time')
plt.ylabel('value')
plt.plot(np.arange(0, 365), time_series[:365])

# %%
# RNN학습을 위한 데이터 전처리

def make_sequence(time_series, n):
  train_data, train_label = [], []

  for i in range(len(time_series)):

    t = time_series[i:(i+n)]

    if (i+n) < len(time_series):
      train_data.append(t)
      train_label.append(time_series[i+n])
    else:
      break

  return np.array(train_data), np.array(train_label)


train_data, train_label = make_sequence(time_series, 10)

# 데이터셋 구조변환
train_data = train_data.reshape(-1, 10, 1) # -1 자동을 의미, 자동 x 10 x 1
train_label = train_label.reshape(-1, 1)

print(train_data.shape)

# 학습데이터, 테스트 데이터
_train_data  = train_data[:300]
_train_label = train_label[:300]

_test_data  = train_data[300:]
_test_label = train_label[300:]
# Out:
# (355, 10, 1)

# %%
# 학습 모델 설계
model = Sequential()

model.add(SimpleRNN(units=32, activation='tanh', input_shape=(10, 1)))
model.add(Dense(1, activation='linear'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_3 (SimpleRNN)     (None, 32)                1088
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,121
# Trainable params: 1,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 설정
model.compile(optimizer='adam', loss='mse', metrics=['acc'])

# %%
#모델 학습하기
model.fit(_train_data, _train_label, epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 3ms/step - loss: 67.7034 - acc: 0.0000e+00
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 55.5994 - acc: 0.0000e+00
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 46.5851 - acc: 0.0000e+00
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 39.8236 - acc: 0.0000e+00
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 34.4312 - acc: 0.0000e+00
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 30.1955 - acc: 0.0000e+00
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 26.6184 - acc: 0.0000e+00
# Epoch 8/100
# 10/10 [==============================] - 0s 4ms/step - loss: 23.7566 - acc: 0.0000e+00
# Epoch 9/100
# 10/10 [==============================] - 0s 4ms/step - loss: 21.4059 - acc: 0.0000e+00
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.5300 - acc: 0.0000e+00
# Epoch 11/100
# 10/10 [==============================] - 0s 5ms/step - loss: 18.0193 - acc: 0.0000e+00
# Epoch 12/100
# 10/10 [==============================] - 0s 4ms/step - loss: 16.8253 - acc: 0.0000e+00
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 15.6312 - acc: 0.0000e+00
# Epoch 14/100
# 10/10 [==============================] - 0s 4ms/step - loss: 14.6998 - acc: 0.0000e+00
# Epoch 15/100
# 10/10 [==============================] - 0s 4ms/step - loss: 13.9733 - acc: 0.0000e+00
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 13.2873 - acc: 0.0000e+00
# Epoch 17/100
# 10/10 [==============================] - 0s 4ms/step - loss: 12.6485 - acc: 0.0000e+00
# Epoch 18/100
# 10/10 [==============================] - 0s 3ms/step - loss: 12.1342 - acc: 0.0000e+00
# Epoch 19/100
# 10/10 [==============================] - 0s 4ms/step - loss: 11.6629 - acc: 0.0000e+00
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 11.1366 - acc: 0.0000e+00
# Epoch 21/100
# 10/10 [==============================] - 0s 4ms/step - loss: 10.7972 - acc: 0.0000e+00
# Epoch 22/100
# 10/10 [==============================] - 0s 4ms/step - loss: 10.5427 - acc: 0.0000e+00
# Epoch 23/100
# 10/10 [==============================] - 0s 3ms/step - loss: 10.1755 - acc: 0.0000e+00
# Epoch 24/100
# 10/10 [==============================] - 0s 4ms/step - loss: 9.8646 - acc: 0.0000e+00
# Epoch 25/100
# 10/10 [==============================] - 0s 5ms/step - loss: 9.5768 - acc: 0.0000e+00
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.3666 - acc: 0.0000e+00
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.2304 - acc: 0.0000e+00
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.0103 - acc: 0.0000e+00
# Epoch 29/100
# 10/10 [==============================] - 0s 4ms/step - loss: 8.8347 - acc: 0.0000e+00
# Epoch 30/100
# 10/10 [==============================] - 0s 4ms/step - loss: 8.6944 - acc: 0.0000e+00
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.5873 - acc: 0.0000e+00
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.4520 - acc: 0.0000e+00
# Epoch 33/100
# 10/10 [==============================] - 0s 4ms/step - loss: 8.3883 - acc: 0.0000e+00
# Epoch 34/100
# 10/10 [==============================] - 0s 4ms/step - loss: 8.2653 - acc: 0.0000e+00
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.1933 - acc: 0.0000e+00
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.0957 - acc: 0.0000e+00
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.0778 - acc: 0.0000e+00
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.9513 - acc: 0.0000e+00
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.8735 - acc: 0.0000e+00
# Epoch 40/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.8155 - acc: 0.0000e+00
# Epoch 41/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.7467 - acc: 0.0000e+00
# Epoch 42/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.6929 - acc: 0.0000e+00
# Epoch 43/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.6303 - acc: 0.0000e+00
# Epoch 44/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.6028 - acc: 0.0000e+00
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.5567 - acc: 0.0000e+00
# Epoch 46/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.5291 - acc: 0.0000e+00
# Epoch 47/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.4221 - acc: 0.0000e+00
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.4750 - acc: 0.0000e+00
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.3539 - acc: 0.0000e+00
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.3195 - acc: 0.0000e+00
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.2912 - acc: 0.0000e+00
# Epoch 52/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.2435 - acc: 0.0000e+00
# Epoch 53/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.1969 - acc: 0.0000e+00
# Epoch 54/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.1818 - acc: 0.0000e+00
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.1736 - acc: 0.0000e+00
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.1004 - acc: 0.0000e+00
# Epoch 57/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.0546 - acc: 0.0000e+00
# Epoch 58/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.0180 - acc: 0.0000e+00
# Epoch 59/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.0322 - acc: 0.0000e+00
# Epoch 60/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.8928 - acc: 0.0000e+00
# Epoch 61/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.8705 - acc: 0.0000e+00
# Epoch 62/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.8527 - acc: 0.0000e+00
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.7693 - acc: 0.0000e+00
# Epoch 64/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.7311 - acc: 0.0000e+00
# Epoch 65/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.7308 - acc: 0.0000e+00
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.6476 - acc: 0.0000e+00
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.6158 - acc: 0.0000e+00
# Epoch 68/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.4956 - acc: 0.0000e+00
# Epoch 69/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.4510 - acc: 0.0000e+00
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.4401 - acc: 0.0000e+00
# Epoch 71/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.3747 - acc: 0.0000e+00
# Epoch 72/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.2766 - acc: 0.0000e+00
# Epoch 73/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.3784 - acc: 0.0000e+00
# Epoch 74/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.2231 - acc: 0.0000e+00
# Epoch 75/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.0978 - acc: 0.0000e+00
# Epoch 76/100
# 10/10 [==============================] - 0s 4ms/step - loss: 6.1585 - acc: 0.0000e+00
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.0243 - acc: 0.0000e+00
# Epoch 78/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.8435 - acc: 0.0000e+00
# Epoch 79/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.8087 - acc: 0.0000e+00
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.7882 - acc: 0.0000e+00
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.9037 - acc: 0.0000e+00
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.7307 - acc: 0.0000e+00
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.6606 - acc: 0.0000e+00
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.6711 - acc: 0.0000e+00
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.4839 - acc: 0.0000e+00
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.4152 - acc: 0.0000e+00
# Epoch 87/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.4049 - acc: 0.0000e+00
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.3421 - acc: 0.0000e+00
# Epoch 89/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.3952 - acc: 0.0000e+00
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.4677 - acc: 0.0000e+00
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.2387 - acc: 0.0000e+00
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.4175 - acc: 0.0000e+00
# Epoch 93/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.2230 - acc: 0.0000e+00
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.0937 - acc: 0.0000e+00
# Epoch 95/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.0745 - acc: 0.0000e+00
# Epoch 96/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.0555 - acc: 0.0000e+00
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.0952 - acc: 0.0000e+00
# Epoch 98/100
# 10/10 [==============================] - 0s 3ms/step - loss: 5.1181 - acc: 0.0000e+00
# Epoch 99/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.0347 - acc: 0.0000e+00
# Epoch 100/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.2755 - acc: 0.0000e+00

# %%
#성능평가
model.evaluate(_test_data, _test_label)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 5.4648 - acc: 0.0000e+00
# [5.464757919311523, 0.0]

# %%
#모델 평가하기
result = model.predict(_test_data)
result_range = np.arange(len(_train_label), len(_train_label) + len(result))

result_range

plt.figure(figsize=(10, 5))
plt.xlabel('time')
plt.ylabel('value')

plt.plot(result_range, _test_label, color='orange', label='label')
plt.plot(result_range, result, color='blue', label='result')
plt.show()
